# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ant_spatial = pd.read_excel("spatial_data_revised.xlsx",sheet_name="Colony A")

# %%
col_names = ant_spatial.columns
ant_set = set()
for item in col_names:
    if item.startswith("a"):
        ant_number = item[1:item.find("_")]
        ant_set.add(int(ant_number))
print(len(ant_set))
# Out:
# 100

# %%
antspeed = []
t = np.array(ant_data["time_sec"])
for ant in ant_set:
    antx_index = "a"+str(ant)+"_transformed_x"
    anty_index = "a"+str(ant)+"_transformed_y"
    x = np.array(ant_spatial[antx_index])
    y = np.array(ant_spatial[anty_index])
    isxnan = np.isnan(x)
    x = x[~isxnan]
    y = y[~isxnan]
    tt = t[~isxnan]
    xdiff_sq = np.diff(x)**2
    ydiff_sq = np.diff(y)**2
    tdiff = np.diff(tt)
    dist = np.sqrt(xdiff_sq+ydiff_sq)
    speed = sum(dist/tdiff)
    antspeed.append(speed)
    print("ant: ",ant,"speed: ",sum(dist/tdiff))
# Out:
# ant:  1 speed:  135461.63187276863
# ant:  5 speed:  41060.11007629671
# ant:  521 speed:  32408.146600008833
# ant:  1034 speed:  22948.873280435422
# ant:  12 speed:  122700.18294929435
# ant:  13 speed:  91198.71973887456
# ant:  524 speed:  223737.53823405417
# ant:  525 speed:  49255.80416550122
# ant:  16 speed:  307548.795552399
# ant:  529 speed:  49392.470132438175
# ant:  21 speed:  66787.11245600398
# ant:  23 speed:  40546.17048620079
# ant:  535 speed:  27491.85720498751
# ant:  26 speed:  29975.570634274365
# ant:  540 speed:  204768.47449086446
# ant:  29 speed:  48227.49941542143
# ant:  32 speed:  297425.09396141145
# ant:  545 speed:  25229.91776498933
# ant:  35 speed:  33160.671602439295
# ant:  36 speed:  45432.66736892323
# ant:  39 speed:  17356.804576192637
# ant:  40 speed:  42928.9714759296
# ant:  552 speed:  46613.064336382675
# ant:  42 speed:  47343.6452412679
# ant:  1069 speed:  49874.755304646096
# ant:  45 speed:  13627.143516199985
# ...

# %%
plt.hist(antspeed,bins=30)
# Out:
# (array([ 3., 14., 19., 16., 15.,  4.,  5.,  7.,  2.,  2.,  5.,  2.,  0.,
#          1.,  0.,  1.,  0.,  0.,  0.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,
#          0.,  0.,  0.,  2.]),
#  array([  3052.27345238,  13202.15752238,  23352.04159238,  33501.92566238,
#          43651.80973238,  53801.69380239,  63951.57787239,  74101.46194239,
#          84251.34601239,  94401.23008239, 104551.11415239, 114700.99822239,
#         124850.88229239, 135000.76636239, 145150.65043239, 155300.53450239,
#         165450.41857239, 175600.30264239, 185750.18671239, 195900.07078239,
#         206049.95485239, 216199.83892239, 226349.72299239, 236499.6070624 ,
#         246649.4911324 , 256799.3752024 , 266949.2592724 , 277099.1433424 ,
#         287249.0274124 , 297398.9114824 , 307548.7955524 ]),
#  <BarContainer object of 30 artists>)

# %%
ant = 268
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 171
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 180
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 207
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 421
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 45
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")

# %%
ant = 16
antx_index = "a"+str(ant)+"_transformed_x"
anty_index = "a"+str(ant)+"_transformed_y"
x = np.array(ant_spatial[antx_index])
y = np.array(ant_spatial[anty_index])
isxnan = np.isnan(x)
x = x[~isxnan]
y = y[~isxnan]
tt = t[~isxnan]
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")
