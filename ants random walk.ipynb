# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ant_data = pd.read_excel("spatial_data_revised.xlsx",sheet_name="Colony A")

# %%
ant_data
# Out:
#       frame  time_sec  a1_transformed_x  a1_transformed_y  a1_original_x  \
# 0         1         0               NaN               NaN             -1
# 1         2         2               NaN               NaN             -1
# 2         3         4               NaN               NaN             -1
# 3         4         6               NaN               NaN             -1
# 4         5         8               NaN               NaN             -1
# ...     ...       ...               ...               ...            ...
# 7613   7614     15226               NaN               NaN             -1
# 7614   7615     15228               NaN               NaN             -1
# 7615   7616     15230               NaN               NaN             -1
# 7616   7617     15232               NaN               NaN             -1
# 7617   7618     15234               NaN               NaN             -1
#
#       a1_original_y  a1_transformed_angle  a5_transformed_x  a5_transformed_y  \
# ...

# %%
ant_data["a1_transformed_x"][:30]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28    1670.601074
# 29    1671.491363
# Name: a1_transformed_x, dtype: float64

# %%
x = np.array(ant_data["a1_transformed_x"])[28:]
y = np.array(ant_data["a1_transformed_y"])[28:]
t = np.array(ant_data["time_sec"])[28:]
r = (x**2 + y**2) -x[0]**2 - y[0]**2

# %%
plt.figure(figsize=(9,9))
plt.plot(x,y,"o-")
